# %%
text_adv1 = 'The quick brown for jumps over the Lazy dog'
print(text_adv1)
# Out:
# The quick brown for jumps over the Lazy dog

# %%
5i



jd8 /s7a.fu73; dfmsal5vm84g ;5S9 ;EW4HU DWV4;S 604JPWD6V0[P7W5
                                                          W DO5v
                                                          \
                                                           07 W;D 0488+0-5824]
