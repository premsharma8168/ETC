# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
var  = np.array([1 , 2 , 3 , 4])

co = var.copy()
vi = var.view()
var[1] = 40
print("var  :  " , var)
print()
print("copy :  " , co)
print()
print("view :  " , vi)
# Out:
# var  :   [ 1 40  3  4]
#
# copy :   [1 2 3 4]
#
# view :   [ 1 40  3  4]
